# %% [markdown]
# # The Curse of Dimensionality - Lab
#
# ## Introduction
#
# In this lab, you'll conduct some mathematical simulations to further investigate the consequences of the curse of dimensionality.
#
# ## Objectives
#
# In this lab you will:
#
# - Create and interpret a visual demonstrating how sparsity changes with n for n-dimensional spaces
# - Demonstrate how training time increases exponentially as the number of features increases

# %% [markdown]
# ## Sparseness in N-Dimensional Space
#
# As discussed, points in n-dimensional space become increasingly sparse as the number of dimensions increases. To demonstrate this, you'll write a function to calculate the Euclidean distance between two points. From there, you'll then generate random points in n-dimensional space, calculate their average distance from the origin, and plot the relationship between this average distance and n.

# %% [markdown]
# ## Euclidean Distance
#
# To start, write a function which takes two points, p1 and p2, and returns the Euclidean distance between them. Recall that the Euclidean distance between two points is given by:
#
# $$ d(a,b) = \sqrt{(a_1 - b_1)^2 + (a_2 - b_2)^2 + ... + (a_n - b_n)^2} $$

# %%
import numpy as np

# %%
def euclidean_distance(p1, p2):
    # Initialize Euclidean Distance
    eu_distance = 0
        
    if len(p1) != len(p2):
        print("Cannot calculate Euclidean distance")
    else:
        # Number of dimensions
        n = len(p1)

        # Use a for loop to iterate over each element
        for i in range(n):

            # Calculate the difference, square, and add it
            eu_distance += (p1[i] - p2[i]) ** 2

        # Square root of the final result
        eu_distance = np.sqrt(eu_distance)

        return eu_distance

# %%
A = (2, 3, 5)
B = (1, -1, 0)
euclidean_distance(A, B)
# Out:
# 6.48074069840786

# %% [markdown]
# ## Average Distance From the Origin
#
# To examine the curse of dimensionality, you'll investigate the average distance to the center of n-dimensional space. As you'll see, this average distance increases as the number of dimensions increases. To investigate this, generate 100 random points for various n-dimensional spaces. Investigate n-dimensional spaces from n=1 to n=1000. In each of these, construct the 100 random points using a random number between -10 and 10 for each dimension of the point. From there, calculate the average distance from each of these points to the origin. Finally, plot this relationship on a graph; the x-axis will be n, the number of dimensions, and the y-axis will be the average distance from the origin.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %%
# Create a for loop for the dimensional space
points_distance = []
mean_distance = []
dimensions = range(1, 1001)

for n in dimensions:
    origin = np.zeros(n)
    distance = 0
    # Generate 100 random points
    for num in range(100):
        random_vector = np.random.uniform(-10, 10, n)

        # Compute distance from the origin
        distance = euclidean_distance(origin, random_vector)
        points_distance.append(distance)
    mean_distance.append(sum(points_distance)/len(points_distance))

# %%
# Plot mean distance against dimension
plt.plot(dimensions, mean_distance)
plt.title("Mean Distance of Points Against Number of Dimensions")
plt.xlabel("Number of Dimensions")
plt.ylabel("Mean Distance from the Origin");

# %% [markdown]
# ## Convergence Time
#
# As mentioned before, another issue with increasing the dimension of the feature space is the training time required to fit a machine learning model. While more data will generally lead to better predictive results, it will also substantially increase training time. To demonstrate this, generate lists of random numbers as you did above. Then, use this list of random numbers as a feature in a mock dataset; choose an arbitrary coefficient and multiply the feature vector by this coefficient. Then, sum these feature-coefficient products to get an output, `y`. To spice things up (and not have a completely deterministic relationship), add a normally distributed white noise parameter to your output values. Fit an ordinary least squares model to your generated mock data. Repeat this for a varying number of features, and record the time required to fit the model. (Be sure to only record the time to train the model, not the time to generate the data.) Finally, plot the number of features, n, versus the training time for the subsequent model.

# %%
import pandas as pd
import datetime
from sklearn.linear_model import LinearRegression, Lasso

# %%
# ⏰ Your code may take some time to run

# %% [markdown]
# - Repeat the same experiment for a Lasso penalized regression model

# %%
# ⏰ Your code may take some time to run

# %% [markdown]
# ## Optional (Level Up)
#
# ### Show Just How Slow it Can Go!
#
# If you're up for putting your computer through the wringer and are very patient to allow the necessary computations, try increasing the maximum n from 1000 to 10,000 using Lasso regression. You should see an interesting pattern unveil. See if you can make any hypotheses as to why this might occur!
#
# _Note:_ ⏰ _You can expect your code to take over an hour to run on a 2.7 GHz speed CPU!_

# %%
# ⏰ Your code may take some time to run

# %%
# !cd ..; ls
# Out:
# als-recommender-system-pyspark-lab
# deloitte-cnn
# dsc-arma-models-statsmodels
# dsc-arma-models-statsmodels-lab
# dsc-aws-s3
# dsc-basic-time-series-models
# dsc-basic-time-series-models-lab
# dsc-bert
# dsc-building-a-cnn-from-scratch
# dsc-classification-with-word-embeddings-codealong
# dsc-collaborative-filtering-singular-value-decomposition
# dsc-context-free-grammars-codealong
# dsc-convolutional-neural-networks-codealong
# dsc-corpus-statistics-lab
# dsc-corr-autocorr-in-time-series
# dsc-corr-autocorr-in-time-series-lab
# dsc-curse-of-dimensionality-lab
# dsc-data-pipeline-lab
# dsc-deeper-neural-networks
# dsc-deeper-neural-networks-lab
# dsc-facebook-prophet-lab
# dsc-flask-deployment
# dsc-flask-intro
# dsc-generating-word-embeddings-lab
# dsc-graph-theory-shortest-path
# dsc-graph-theory-shortest-path-lab
# dsc-hierarchical-agglomerative-clustering-codealong
# dsc-image-classification-lab
# dsc-image-classification-with-mlps-lab
# dsc-implementing-recommender-systems
# dsc-implementing-recommender-systems-lab
# dsc-introduction-to-keras
# dsc-introduction-to-keras-lab
# dsc-introduction-to-neural-networks
# dsc-introduction-to-neural-networks-lab
# dsc-introduction-to-time-series
# dsc-k-means-clustering-lab
# dsc-machine-learning-with-spark-lab
# dsc-machine-learning-with-spark-v2-4
# dsc-managing-time-series-data-lab
# dsc-market-segmentation-clustering-lab
# dsc-matrix-factorization-als
# dsc-network-clustering
# dsc-network-clustering-lab
# dsc-network-community-detection-lab
# dsc-network-recomendation-systems-lab
# dsc-network-recommendation-systems
# dsc-networkX-intro
# dsc-networkX-intro-lab
# dsc-nlp-lab
# dsc-node-centrality
# dsc-node-centrality-lab
# dsc-pca-and-digital-image-processing
# dsc-pca-and-digital-image-processing-lab
# dsc-pca-and-pipelines-v2-1
# dsc-pca-covariance-matrix-eigendecomp
# dsc-pca-in-scikitlearn
# dsc-pca-in-scikitlearn-lab
# dsc-pca-numpy-lab
# dsc-performing-principle-component-analysis
# dsc-productionizing-models-with-sagemaker
# dsc-regular-expressions-codealong
# dsc-removing-trends
# dsc-removing-trends-lab
# dsc-resilient-distributed-datasets-rdd-lab
# dsc-sarima-models-lab
# dsc-sparkcontext
# dsc-spark-dataframes
# dsc-spark-docker-installation
# dsc-testing-for-trends-lab
# dsc-text-classification-lab
# dsc-time-series-decomposition
# dsc-tuning-neural-networks-from-start-to-finish-lab-v2-1
# dsc-tuning-neural-networks-with-normalization-lab-v2-1
# dsc-tuning-neural-networks-with-regularization-lab-v2-1
# dsc-types-of-trends
# dsc-using-pretrained-networks
# dsc-using-pretrained-networks-codealong
# dsc-visualizing-activation-functions-lab
# dsc-visualizing-intermediate-activations
# dsc-visualizing-time-series-data-lab
# dsc-word-count-with-map-reduce-lab
# dsc-word-vectorization-lab
# dsc-xgboost-deloitte-lab
# dsc-xgboost-deloitte-pyspark

# %%
# !cd ..; cd ..; git clone https://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@github.com/leogachimu/data_science_flatiron_content
# Out:
# Cloning into 'data_science_flatiron_content'...
# remote: Enumerating objects: 1559, done.
# remote: Counting objects: 100% (300/300), done.
# remote: Compressing objects: 100% (243/243), done.
# remote: Total 1559 (delta 35), reused 300 (delta 35), pack-reused 1259
# Receiving objects: 100% (1559/1559), 76.07 MiB | 26.78 MiB/s, done.
# Resolving deltas: 100% (213/213), done.
# Updating files: 100% (2358/2358), done.

# %%
# !cd ..; cd ..; rm -rf data_science_flatiron_content

# %%
#!cd ..; cd ..; cd data_science_flatiron_content/; ls
# !cd ..; cd ..; ls
# Out:
# data_science_flatiron_content  Phase4

# %%
# !cd ..; cd ..; cp -r Phase4 data_science_flatiron_content/

# %% [markdown]
# ## Summary
#
# In this lab, you conducted various simulations to investigate the curse of dimensionality. This demonstrated some of the caveats of working with large datasets with an increasing number of features. With that, the next section will explore principal component analysis, a means of reducing the number of features in a dataset while preserving as much information as possible.
