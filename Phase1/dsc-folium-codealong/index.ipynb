# %% [markdown]
# # Folium - Codealong
#
# ## Introduction
#
# In this codealong, we'll take a look at how to create an interactive map using the Folium package. From there, we'll return to APIs in the final lab for the day where you'll make an interactive map from your requests to the API!
#
# ## Objectives
#
# You will be able to:
#
# * Create maps using Folium

# %% [markdown]
# ## Creating a Basemap
#
# Here we'll take a look at creating a basemap over the London region!

# %%
import folium

lat = 51.51
long = -0.14

#Create a map of the area
base_map = folium.Map([lat, long], zoom_start=13)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc2dbade73062915d0dd94f57b7a156a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc2dbade73062915d0dd94f57b7a156a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_bc2dbade73062915d0dd94f57b7a156a = L.map(
#                 &quot;map_bc2dbade73062915d0dd94f57b7a156a&quot;,
#                 {
#                     center: [51.51, -0.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70d7b0cf6a7736cee9563be584f648c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bc2dbade73062915d0dd94f57b7a156a);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Adding Markers to the Map
#
# Great! Now let's take a look at adding little markers to our map!
#
# **Note:** you may have to zoom out to see all of the markers!

# %%
import numpy as np

#Generate some random locations to add to our map
x = [lat + np.random.uniform(-.1,.1) for i in range(20)]
y = [long + np.random.uniform(-.1,.1) for i in range(20)]
points = list(zip(x, y))
for p in points:
    lat = p[0]
    long = p[1]
    marker = folium.Marker(location=[lat, long])
    marker.add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b38eb2f6b246d9987daf380000b830a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b38eb2f6b246d9987daf380000b830a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b38eb2f6b246d9987daf380000b830a0 = L.map(
#                 &quot;map_b38eb2f6b246d9987daf380000b830a0&quot;,
#                 {
#                     center: [51.51, -0.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e598e40b41cc73ac1556ffc0526fa85 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_5e252a72f9706a63da18f1fbfa7c4e68 = L.marker(
#                 [51.46257372208247, -0.22047305174665321],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_39f5bb6c9aade55319a77ea5c9f0ffae = L.marker(
#                 [51.5749214339033, -0.12403277625964834],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_e0643f49ca6a4b7bad7dd143e9ad3c41 = L.marker(
#                 [51.44510048191787, -0.048282874498009276],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_80647c11f828a6cb6dad237a2650b56d = L.marker(
#                 [51.45092432162621, -0.10609331470660405],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_e44c0dd37470e80d0d265de35c5f1183 = L.marker(
#                 [51.5006146981589, -0.06745984750025227],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_b9f347fa8693877ad3cd0ee93b0ff7d5 = L.marker(
#                 [51.512264137486326, -0.07739358869428081],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_01f9c0423f52cde2daaa68335eaf55e1 = L.marker(
#                 [51.53280469501677, -0.0767061769961957],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_0cd68b18f6ec0128324a6d9cd9c9e8e7 = L.marker(
#                 [51.53510970702358, -0.04682464752579793],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_f25d1888f13154e46aa2536dddd7ad21 = L.marker(
#                 [51.53722925510828, -0.048533478102370076],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_5339843f718224464c5ffac8daeaceb5 = L.marker(
#                 [51.415710423179526, -0.06448324341755857],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_ed04933620295655d04b89628368857a = L.marker(
#                 [51.508170346653905, -0.0622433190318912],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_ba9d2ec04076631f624d3acf212c545e = L.marker(
#                 [51.42908788937909, -0.07680937596533768],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_452767a070d3a3b34a708b6fc05a8012 = L.marker(
#                 [51.48655157081323, -0.19545837629886825],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_ef0c6a06466d4074e03db9a02821789c = L.marker(
#                 [51.491357750855315, -0.10662895068312758],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_4bca667a56453ad00323089e2a830b53 = L.marker(
#                 [51.46841620906601, -0.05817733004904818],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_12fbc78205e7c3ab62cddd3c975eb0da = L.marker(
#                 [51.48720213248849, -0.15340022144318582],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_c4ab52336a0da38b239e28ceec609e21 = L.marker(
#                 [51.486078921985545, -0.14346223927443558],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_83fd6e0035cc718a82608350818b47d7 = L.marker(
#                 [51.50603679443472, -0.1430769530722889],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_3c82e923940ce38df352ea03b3d97365 = L.marker(
#                 [51.60897257373617, -0.056613198459160574],
#                 {}
#             ).addTo(map_b38eb2f6b246d9987daf380000b830a0);
#
#
#             var marker_cd0f36f7c99de6b00fd3d2bf6f35e937 = L.marker

# %% [markdown]
# ## Adding Pop-up Boxes to Our Markers
#
# Often we may wish to not only place markers on the map, but to create interactive pop-ups which display information to that location. To do this, we can add a popup to our markers when adding them to the map!

# %%
for p in points:
    lat = p[0]
    long = p[1]
    popup_text = "Latitude: {}, Longitude: {}".format(lat,long)
    popup = folium.Popup(popup_text, parse_html=True)
    marker = folium.Marker(location=[lat, long], popup=popup)
    marker.add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc2dbade73062915d0dd94f57b7a156a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc2dbade73062915d0dd94f57b7a156a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_bc2dbade73062915d0dd94f57b7a156a = L.map(
#                 &quot;map_bc2dbade73062915d0dd94f57b7a156a&quot;,
#                 {
#                     center: [51.51, -0.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70d7b0cf6a7736cee9563be584f648c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bc2dbade73062915d0dd94f57b7a156a);
#
#
#             var marker_f7b6e0ffe7fc0ec968b9305d56a39379 = L.marker(
#                 [51.46257372208247, -0.22047305174665321],
#                 {}
#             ).addTo(map_bc2dbade73062915d0dd94f57b7a156a);
#
#
#         var popup_8c7519d93890e1a9685cbf4ca38c1ee8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3699d4e231fee5b639727b9e1c1a88f0 = $(`&lt;div id=&quot;html_3699d4e231fee5b639727b9e1c1a88f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 51.46257372208247, Longitude: -0.22047305174665321&lt;/div&gt;`)[0];
#             popup_8c7519d93890e1a9685cbf4ca38c1ee8.setContent(html_3699d4e231fee5b639727b9e1c1a88f0);
#
#
#         marker_f7b6e0ffe7fc0ec968b9305d56a39379.bindPopup(popup_8c7519d93890e1a9685cbf4ca38c1ee8)
#         ;
#
#
#
#
#             var marker_e9b534aa962d33c1d512aff198ede75c = L.marker(
#                 [51.5749214339033, -0.12403277625964834],
#                 {}
#             ).addTo(map_bc2dbade73062915d0dd94f57b7a156a);
#
#
#         var popup_e66c863fe83b319cf507d3e8e84b776d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f682341fec12cdae9f6d764156fe5e35 = $(`&lt;div id=&quot;html_f682341fec12cdae9f6d764156fe5e35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 51.5749214339033, Longitude: -0.12403277625964834&lt;/div&gt;`)[0];
#             popup_e66c863fe83b319cf507d3e8e84b776d.setContent(html_f682341fec12cdae9f6d764156fe5e35);
#
#
#         marker_e9b534aa962d33c1d512aff198ede75c.bindPopup(popup_e66c863fe83b319cf507d3e8e84b776d)
#         ;
#
#
#
#
#             var marker_b63abb44a9d02899e4a72b7711dd13a9 = L.marker(
#                 [51.44510048191787, -0.048282874498009276],
#                 {}
#             ).addTo(map_bc2dbade73062915d0dd94f57b7a156a);
#
#
#         var popup_c9068646f7234bf3aafbd1d3970661d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1c02a46905c3d1ef2c8a8dc0b7388e87 = $(`&lt;div id=&quot;html_1c02a46905c3d1ef2c8a8dc0b7388e87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 51.44510048191787, Longitude: -0.048282874498009276&lt;/div&gt;`)[0];
#             popup_c9068646f7234bf3aafbd1d3970661d5.setContent(html_1c02a46905c3d1ef2c8a8dc0b7388e87);
#
#
#         marker_b63abb44a9d02899e4a72b7711dd13a9.bindPopup(popup_c9068646f7234bf3aafbd1d3970661d5)
#         ;
#
#
#
#
#             var marker_ecbb1c637a564e54b2fc868eccdce1b4 = L.marker(
#                 [51.45092432162621, -0.10609331470660405],
#                 {}
#             ).addTo(map_bc2dbade73062915d0dd94f57b7a156a);
#
#
#         var popup_e05fad3beafca61c0c602b8f390ee950 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1832a3019cb09732a39a0a5c99c38422 = $(`&lt;div id=&quot;html_1832a3019cb09732a39a0a5c99c38422&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 51.45092432162621, Longitude: -0.10609331470660405&lt;/div&gt;`)[0];
#             popup_e05fad3beafca61c0c602b8f390ee950.setContent(html_1832a3019cb09732a39a0a5c99c38422);
#
#
#         marker_ecbb1c637a564e54b2fc868eccdce1b4.bindPopup(popup_e05fad3beafca61c0c602b8f390ee950)
#         ;
#
#
#
#
#             var marker_2e3eb8b4ff7f7516332ad671855fcb45 = L.marker(
#                 [51.5006146981589, -0.06745984750025227],
#                 {}
#             ).addTo(map_bc2dbade73062915d0dd94f57b7a156a);
#
#
#         var popup_af1f6f891e2cc15be265dd709e24be4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_713e9919952ebea0e980911e2fc089ae = $(`&lt;div id=&quot;html_713e9919952ebea0e980911e2fc089ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 51.5006146981589, Longitude: -0.06745984750025227&lt;/div&gt;`)[0];
#             popup_af1f6f891e2cc15be265dd709e24be4e.setContent(html_713e9919952ebea0e980911e2fc089ae);
#
#
#         marker_2e3eb8b4ff7f7516332ad671855fcb45.bindPopup(popup_af1f6f891e2cc15be265dd709e24be4e)
#         ;
#
#
#
#
#             var marker_7a2909a4be0a4fd7a1ca1660fb993b43 = L.marker(
#                 [51.512264137486326, -0.0773

# %% [markdown]
# Now, if you click on the map markers, you should see a little information box pop up!
#
# ## Summary
#
# In this codealong, we learned how to use Folium to create some cool interactive maps with only a few lines of Python code!
