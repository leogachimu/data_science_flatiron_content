# %% [markdown]
# # The Normal Distribution - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, you'll learn how to generate random normal distributions in Python. You'll learn how to visualize a histogram and build a density function using the formula.
#
# ## Objectives
# You will be able to:
#
# * Use `numpy` to generate a random normal distribution
# * Calculate the density function for normal distributions with a Python function
# * Plot and interpret density plots and comment on the shape of the plot

# %% [markdown]
# ## A quick refresher!
#
# Here's the formula for the normal distribution density function once more:
#
# $$ \large N(x) = \dfrac{1}{\sigma \sqrt {2\pi }}e^{-\dfrac{(x-\mu)^2}{2\sigma^2}}$$
#
# Here,
# - $\mu$ is the mean
# - $\sigma$ is the standard deviation
# - $\pi \approx 3.14159 $
# - $ e \approx 2.71828 $

# %% [markdown]
# ## First generate a normal distribution containing 5000 values with $\mu=14$ and $\sigma = 2.8$

# %%
# Generate a random normal variable with given parameters , n=5000
import numpy as np

mu = 14
sigma = 2.8
n = 5000
sequence = np.random.normal(mu, sigma, n)

# %% [markdown]
# ## Calculate a normalized histogram for this distribution in matplotlib, with bin size = 20
#
# Make sure to get the bin positions and counts for each of the obtained bins. You can use [official documentation](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html) to view input and output options for `plt.hist()`

# %%
# Import matplotlib library
import matplotlib.pyplot as plt

# Plot the histogram
counts, bins, ignored = plt.hist(sequence, bins=20, density=True)

# Set the xticks
plt.xticks(bins, rotation='vertical')

# Define the title, x and y labels
plt.title('Normalized Histogram for a Normal Distribution')
plt.xlabel('Class Intervals')
plt.ylabel('Density');

# %% [markdown]
# ## Use the formula to calculate the density function with $\mu$, $\sigma$ and bin information obtained before

# %%
bins
# Out:
# array([ 3.23287342,  4.26381575,  5.29475808,  6.32570041,  7.35664274,
#         8.38758507,  9.4185274 , 10.44946973, 11.48041206, 12.51135439,
#        13.54229672, 14.57323905, 15.60418138, 16.63512371, 17.66606604,
#        18.69700837, 19.7279507 , 20.75889303, 21.78983536, 22.82077769,
#        23.85172002])

# %%
# Calculate the normal Density function 
density = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
density
# Out:
# array([8.76536275e-05, 3.37465262e-04, 1.13452072e-03, 3.33058073e-03,
#        8.53791203e-03, 1.91120628e-02, 3.73583449e-02, 6.37663955e-02,
#        9.50430329e-02, 1.23700906e-01, 1.40588453e-01, 1.39524541e-01,
#        1.20913760e-01, 9.15008289e-02, 6.04642273e-02, 3.48896138e-02,
#        1.75799646e-02, 7.73506566e-03, 2.97189999e-03, 9.97076667e-04,
#        2.92110450e-04])

# %%
density1 = 1/(2.8 * np.sqrt(2 * np.pi)) * np.exp( - (20 - 14)**2 / (2 * 2.8**2))
density1
# from scipy.stats import norm

# pdf = norm.pdf(20, 14, 2.8)
# pdf
# Out:
# 0.014343243014608252

# %% [markdown]
# ## Plot the histogram and density function

# %%
# Plot histogram along with the density function
fig, ax=plt.subplots()

# Plot the histogram
ax.hist(sequence, bins=bins, density=True, label='Normalized Histogram')

# Plot the Probability Density Function
ax.plot(bins, density, label='Probability Density Function')
plt.xticks(bins, rotation='vertical')

# Define the title, x and y labels
plt.title('Normalized Histogram and Density Function')
plt.xlabel('Class Intervals')
plt.ylabel('Density')
plt.legend(loc='upper right', fontsize="8");

# %% [markdown]
# ## Visualize the distribution using seaborn and plot the KDE

# %%
# Use seaborn to plot the histogram with KDE
import seaborn as sns

# Plot the KDE
sns.displot(sequence, bins=bins, kde=True)
plt.xticks(bins, rotation='vertical')

# Define the title, x and y labels
plt.title('Kernel Density Function')
plt.xlabel('Class Intervals')
plt.ylabel('Density');

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to generate random normal distributions in Python using Numpy. You also calculated the density for normal distributions using the general formula as well as seaborn's KDE. Next, you'll move on to learn about the standard normal distribution and how normal distributions are used to answer analytical questions.
