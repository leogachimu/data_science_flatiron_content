# %% [markdown]
# # Resampling Methods - Lab
#
# ## Introduction
#
# Now that you have some preliminary background on bootstrapping, jackknife, and permutation tests, its time to practice those skills by coding them into functions. You'll then apply these tests to a hypothesis test and compare the results to a parametric t-test.
#
# ## Objectives
#
# In this lab you will:
#
# * Create functions that perform resampling techniques and use them on datasets

# %% [markdown]
# ## Bootstrap sampling
#
#
# Bootstrap sampling works by combining two distinct samples into a universal set and generating random samples from this combined sample space in order to compare these random splits to the two original samples. The idea is to see if the difference between the two **original** samples is statistically significant. If similar differences can be observed through the random generation of samples, then the observed differences are not actually significant.
#
#
# Write a function to perform bootstrap sampling. The function should take in two samples A and B. The two samples need not be the same size. From this, create a universal sample by combining A and B. Then, create a resampled universal sample of the same size using random sampling with replacement. Finally, split this randomly generated universal set into two samples which are the same size as the original samples, A and B. The function should return these resampled samples.
#
# Example:
#
# ```python
#
# A = [1,2,3]
# B = [2,2,5,6]
#
# Universal_Set = [1,2,2,2,3,5,6]
# Resampled_Universal_Set = [6, 2, 3, 2, 1, 1, 2] # Could be different (randomly generated with replacement)
#
# Resampled_A = [6,2,3]
# Resampled_B = [2,1,1,2]
# ```

# %%
import numpy as np
import scipy as stats

def bootstrap(A, B):
    Universal_Set = A + B
    Resampled_Universal_Set = list(np.random.choice(Universal_Set, 
                                               size=len(Universal_Set), replace=True))
    Resampled_A = Resampled_Universal_Set[:len(A)]
    Resampled_B = Resampled_Universal_Set[len(A):]
    return Resampled_A, Resampled_B

A = [1,2,3]
B = [2,2,5,6] 

print(f"Resampled sample A :>, {Resampled_A}")
print(f"Resampled sample B :>, {Resampled_B}")
# Out:
# Resampled sample A :>, [5, 5, 2]
# Resampled sample B :>, [1, 2, 3, 5]

# %% [markdown]
# ## Jackknife
#
# Write a function that creates additional samples by removing one element at a time. The function should do this for each of the `n` items in the original sample, returning `n` samples, each with `n-1` members.

# %%
def jack1(sample):
    """This function should take in a list of n observations and return n lists
    each with one member (presumably the nth) removed."""
    new_sample_list = []
    for n in range(len(sample)):
        new_sample = sample[:len(sample)-n]
        new_sample_list.append(new_sample)
    return new_sample_list

sample = [1,2,2,2,3,5,6]
print(jack1(sample))
# Out:
# [[1, 2, 2, 2, 3, 5, 6], [1, 2, 2, 2, 3, 5], [1, 2, 2, 2, 3], [1, 2, 2, 2], [1, 2, 2], [1, 2], [1]]

# %%
def jack2(sample):
    """This function should take in a list of n observations and return n lists
    each with one member (presumably the nth) removed."""
    samples = []
    for i in range(len(sample)):
        new_sample = sample[:i] + sample[i+1:]
        samples.append(new_sample)
    return samples

sample = [1,2,2,2,3,5,6]
print(jack2(sample))
# Out:
# [[2, 2, 2, 3, 5, 6], [1, 2, 2, 3, 5, 6], [1, 2, 2, 3, 5, 6], [1, 2, 2, 3, 5, 6], [1, 2, 2, 2, 5, 6], [1, 2, 2, 2, 3, 6], [1, 2, 2, 2, 3, 5]]

# %%
sample = [1,2,2,2,3,5,6]
sample[1:]
# Out:
# [2, 2, 2, 3, 5, 6]

# %% [markdown]
# ## Permutation testing
#
# Define a function that generates all possible, equally sized, two set splits of two sets A and B. Sets A and B need not be the same size, but all of the generated two set splits should be of equal size. For example, if we had a set with 5 members and a set with 7 members, the function would return all possible 5-7 ordered splits of the 12 items.
#
# > Note that these are actually combinations! However, as noted previously, permutation tests really investigate possible regroupings of the data observations, so calculating combinations is a more efficient approach!
#
#
# Here's a more in depth example:
#
# ```python
# A = [1, 2, 2]
# B = [1, 3]
# combT(A, B)
# [([1,2,2], [1,3]),
#  ([1,2,3], [1,2]),
#  ([1,1,2], [2,3]),
#  ([1,1,3], [2,2]),
#  ([2,2,3], [1,1])]
#
# ```
#
# These are all the possible 3-2 member splits of the 5 elements: 1, 1, 2, 2, 3.

# %%
def combT(a,b):
    # Your code here

# %%
A = [1, 2, 2]
B = [1, 3]
combined = A + B
import itertools
combs = list(itertools.combinations(combined, len(A)))
combs
# Out:
# [(1, 2, 2),
#  (1, 2, 1),
#  (1, 2, 3),
#  (1, 2, 1),
#  (1, 2, 3),
#  (1, 1, 3),
#  (2, 2, 1),
#  (2, 2, 3),
#  (2, 1, 3),
#  (2, 1, 3)]

# %%
from itertools import combinations

def equally_sized_splits(A, B):
    all_splits = []
    total_len = len(A) + len(B)

    for split_len in range(1, total_len // 2 + 1):
        for split_indices_A in combinations(range(len(A)), split_len):
            split_indices_B = tuple(i for i in range(len(B)) if i not in split_indices_A)
            split_A = [A[i] for i in split_indices_A]
            split_B = [B[i] for i in split_indices_B]
            all_splits.append((split_A, split_B))

    return all_splits

# Example usage
list_A = [1, 2, 3, 4, 5]
list_B = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

splits = equally_sized_splits(list_A, list_B)
for i, (split_A, split_B) in enumerate(splits):
    print(f"Split {i + 1}: List A: {split_A}, List B: {split_B}")
# Out:
# Split 1: List A: [1], List B: ['B', 'C', 'D', 'E', 'F', 'G']
# Split 2: List A: [2], List B: ['A', 'C', 'D', 'E', 'F', 'G']
# Split 3: List A: [3], List B: ['A', 'B', 'D', 'E', 'F', 'G']
# Split 4: List A: [4], List B: ['A', 'B', 'C', 'E', 'F', 'G']
# Split 5: List A: [5], List B: ['A', 'B', 'C', 'D', 'F', 'G']
# Split 6: List A: [1, 2], List B: ['C', 'D', 'E', 'F', 'G']
# Split 7: List A: [1, 3], List B: ['B', 'D', 'E', 'F', 'G']
# Split 8: List A: [1, 4], List B: ['B', 'C', 'E', 'F', 'G']
# Split 9: List A: [1, 5], List B: ['B', 'C', 'D', 'F', 'G']
# Split 10: List A: [2, 3], List B: ['A', 'D', 'E', 'F', 'G']
# Split 11: List A: [2, 4], List B: ['A', 'C', 'E', 'F', 'G']
# Split 12: List A: [2, 5], List B: ['A', 'C', 'D', 'F', 'G']
# Split 13: List A: [3, 4], List B: ['A', 'B', 'E', 'F', 'G']
# Split 14: List A: [3, 5], List B: ['A', 'B', 'D', 'F', 'G']
# Split 15: List A: [4, 5], List B: ['A', 'B', 'C', 'F', 'G']
# Split 16: List A: [1, 2, 3], List B: ['D', 'E', 'F', 'G']
# Split 17: List A: [1, 2, 4], List B: ['C', 'E', 'F', 'G']
# Split 18: List A: [1, 2, 5], List B: ['C', 'D', 'F', 'G']
# Split 19: List A: [1, 3, 4], List B: ['B', 'E', 'F', 'G']
# Split 20: List A: [1, 3, 5], List B: ['B', 'D', 'F', 'G']
# Split 21: List A: [1, 4, 5], List B: ['B', 'C', 'F', 'G']
# Split 22: List A: [2, 3, 4], List B: ['A', 'E', 'F', 'G']
# Split 23: List A: [2, 3, 5], List B: ['A', 'D', 'F', 'G']
# Split 24: List A: [2, 4, 5], List B: ['A', 'C', 'F', 'G']
# Split 25: List A: [3, 4, 5], List B: ['A', 'B', 'F', 'G']
# Split 26: List A: [1, 2, 3, 4], List B: ['E', 'F', 'G']
# Split 27: List A: [1, 2, 3, 5], List B: ['D', 'F', 'G']
# Split 28: List A: [1, 2, 4, 5], List B: ['C', 'F', 'G']
# Split 29: List A: [1, 3, 4, 5], List B: ['B', 'F', 'G']
# Split 30: List A: [2, 3, 4, 5], List B: ['A', 'F', 'G']
# Split 31: List A: [1, 2, 3, 4, 5], List B: ['F', 'G']

# %%
from itertools import permutations

def equally_sized_splits(A, B):
    all_splits = []

    for perm_A in permutations(A):
        for perm_B in permutations(B):
            split_A = list(perm_A)
            split_B = list(perm_B)
            all_splits.append((split_A, split_B))

    return all_splits

# Example usage
list_A = [1, 2, 3, 4, 5]
list_B = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

splits = equally_sized_splits(list_A, list_B)
for i, (split_A, split_B) in enumerate(splits):
    print(f"Split {i + 1}: List A: {split_A}, List B: {split_B}")
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Split 584291: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'C', 'F', 'B', 'E']
# Split 584292: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'C', 'F', 'E', 'B']
# Split 584293: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'E', 'B', 'C', 'F']
# Split 584294: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'E', 'B', 'F', 'C']
# Split 584295: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'E', 'C', 'B', 'F']
# Split 584296: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'E', 'C', 'F', 'B']
# Split 584297: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'E', 'F', 'B', 'C']
# Split 584298: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'E', 'F', 'C', 'B']
# Split 584299: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'F', 'B', 'C', 'E']
# Split 584300: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'F', 'B', 'E', 'C']
# Split 584301: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'F', 'C', 'B', 'E']
# Split 584302: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'F', 'C', 'E', 'B']
# Split 584303: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'F', 'E', 'B', 'C']
# Split 584304: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'A', 'F', 'E', 'C', 'B']
# Split 584305: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'A', 'C', 'E', 'F']
# Split 584306: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'A', 'C', 'F', 'E']
# Split 584307: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'A', 'E', 'C', 'F']
# Split 584308: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'A', 'E', 'F', 'C']
# Split 584309: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'A', 'F', 'C', 'E']
# Split 584310: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'A', 'F', 'E', 'C']
# Split 584311: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'C', 'A', 'E', 'F']
# Split 584312: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'C', 'A', 'F', 'E']
# Split 584313: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'C', 'E', 'A', 'F']
# Split 584314: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'C', 'E', 'F', 'A']
# Split 584315: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'C', 'F', 'A', 'E']
# Split 584316: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'C', 'F', 'E', 'A']
# Split 584317: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'E', 'A', 'C', 'F']
# Split 584318: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'E', 'A', 'F', 'C']
# Split 584319: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'E', 'C', 'A', 'F']
# Split 584320: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'E', 'C', 'F', 'A']
# Split 584321: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'E', 'F', 'A', 'C']
# Split 584322: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'E', 'F', 'C', 'A']
# Split 584323: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'F', 'A', 'C', 'E']
# Split 584324: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'F', 'A', 'E', 'C']
# Split 584325: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'F', 'C', 'A', 'E']
# Split 584326: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'F', 'C', 'E', 'A']
# Split 584327: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'F', 'E', 'A', 'C']
# Split 584328: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'B', 'F', 'E', 'C', 'A']
# Split 584329: List A: [5, 4, 1, 3, 2], List B: ['G', 'D', 'C', 'A', 
List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'B', 'C', 'F', 'D']
# Split 584403: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'B', 'D', 'C', 'F']
# Split 584404: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'B', 'D', 'F', 'C']
# Split 584405: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'B', 'F', 'C', 'D']
# Split 584406: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'B', 'F', 'D', 'C']
# Split 584407: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'C', 'B', 'D', 'F']
# Split 584408: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'C', 'B', 'F', 'D']
# Split 584409: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'C', 'D', 'B', 'F']
# Split 584410: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'C', 'D', 'F', 'B']
# Split 584411: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'C', 'F', 'B', 'D']
# Split 584412: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'C', 'F', 'D', 'B']
# Split 584413: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'D', 'B', 'C', 'F']
# Split 584414: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'D', 'B', 'F', 'C']
# Split 584415: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'D', 'C', 'B', 'F']
# Split 584416: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'D', 'C', 'F', 'B']
# Split 584417: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'D', 'F', 'B', 'C']
# Split 584418: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'D', 'F', 'C', 'B']
# Split 584419: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'F', 'B', 'C', 'D']
# Split 584420: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'F', 'B', 'D', 'C']
# Split 584421: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'F', 'C', 'B', 'D']
# Split 584422: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'F', 'C', 'D', 'B']
# Split 584423: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'F', 'D', 'B', 'C']
# Split 584424: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'A', 'F', 'D', 'C', 'B']
# Split 584425: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'A', 'C', 'D', 'F']
# Split 584426: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'A', 'C', 'F', 'D']
# Split 584427: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'A', 'D', 'C', 'F']
# Split 584428: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'A', 'D', 'F', 'C']
# Split 584429: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'A', 'F', 'C', 'D']
# Split 584430: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'A', 'F', 'D', 'C']
# Split 584431: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'C', 'A', 'D', 'F']
# Split 584432: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'C', 'A', 'F', 'D']
# Split 584433: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'C', 'D', 'A', 'F']
# Split 584434: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'C', 'D', 'F', 'A']
# Split 584435: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'C', 'F', 'A', 'D']
# Split 584436: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'C', 'F', 'D', 'A']
# Split 584437: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'D', 'A', 'C', 'F']
# Split 584438: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'D', 'A', 'F', 'C']
# Split 584439: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'D', 'C', 'A', 'F']
# Split 584440: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'D', 'C', 'F', 'A']
# Split 584441: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'D', 'F', 'A', 'C']
# Split 584442: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'D', 'F', 'C', 'A']
# Split 584443: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'F', 'A', 'C', 'D']
# Split 584444: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'F', 'A', 'D', 'C']
# Split 584445: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'F', 'C', 'A', 'D']
# Split 584446: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'F', 'C', 'D', 'A']
# Split 584447: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'F', 'D', 'A', 'C']
# Split 584448: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'B', 'F', 'D', 'C', 'A']
# Split 584449: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'A', 'B', 'D', 'F']
# Split 584450: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'A', 'B', 'F', 'D']
# Split 584451: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'A', 'D', 'B', 'F']
# Split 584452: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'A', 'D', 'F', 'B']
# Split 584453: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'A', 'F', 'B', 'D']
# Split 584454: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'A', 'F', 'D', 'B']
# Split 584455: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'B', 'A', 'D', 'F']
# Split 584456: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'B', 'A', 'F', 'D']
# Split 584457: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'B', 'D', 'A', 'F']
# Split 584458: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'B', 'D', 'F', 'A']
# Split 584459: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'B', 'F', 'A', 'D']
# Split 584460: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'B', 'F', 'D', 'A']
# Split 584461: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'D', 'A', 'B', 'F']
# Split 584462: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'D', 'A', 'F', 'B']
# Split 584463: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'D', 'B', 'A', 'F']
# Split 584464: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'D', 'B', 'F', 'A']
# Split 584465: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'D', 'F', 'A', 'B']
# Split 584466: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'D', 'F', 'B', 'A']
# Split 584467: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'F', 'A', 'B', 'D']
# Split 584468: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'F', 'A', 'D', 'B']
# Split 584469: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'F', 'B', 'A', 'D']
# Split 584470: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'F', 'B', 'D', 'A']
# Split 584471: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'F', 'D', 'A', 'B']
# Split 584472: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'C', 'F', 'D', 'B', 'A']
# Split 584473: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'D', 'A', 'B', 'C', 'F']
# Split 584474: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'D', 'A', 'B', 'F', 'C']
# Split 584475: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'D', 'A', 'C', 'B', 'F']
# Split 584476: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'D', 'A', 'C', 'F', 'B']
# Split 584477: List A: [5, 4, 1, 3, 2], List B: ['G', 'E', 'D', 'A', 
List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'E', 'F', 'D', 'G']
# Split 584770: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'E', 'F', 'G', 'D']
# Split 584771: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'E', 'G', 'D', 'F']
# Split 584772: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'E', 'G', 'F', 'D']
# Split 584773: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'F', 'D', 'E', 'G']
# Split 584774: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'F', 'D', 'G', 'E']
# Split 584775: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'F', 'E', 'D', 'G']
# Split 584776: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'F', 'E', 'G', 'D']
# Split 584777: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'F', 'G', 'D', 'E']
# Split 584778: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'F', 'G', 'E', 'D']
# Split 584779: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'G', 'D', 'E', 'F']
# Split 584780: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'G', 'D', 'F', 'E']
# Split 584781: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'G', 'E', 'D', 'F']
# Split 584782: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'G', 'E', 'F', 'D']
# Split 584783: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'G', 'F', 'D', 'E']
# Split 584784: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'B', 'G', 'F', 'E', 'D']
# Split 584785: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'B', 'E', 'F', 'G']
# Split 584786: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'B', 'E', 'G', 'F']
# Split 584787: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'B', 'F', 'E', 'G']
# Split 584788: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'B', 'F', 'G', 'E']
# Split 584789: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'B', 'G', 'E', 'F']
# Split 584790: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'B', 'G', 'F', 'E']
# Split 584791: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'E', 'B', 'F', 'G']
# Split 584792: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'E', 'B', 'G', 'F']
# Split 584793: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'E', 'F', 'B', 'G']
# Split 584794: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'E', 'F', 'G', 'B']
# Split 584795: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'E', 'G', 'B', 'F']
# Split 584796: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'E', 'G', 'F', 'B']
# Split 584797: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'F', 'B', 'E', 'G']
# Split 584798: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'F', 'B', 'G', 'E']
# Split 584799: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'F', 'E', 'B', 'G']
# Split 584800: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'F', 'E', 'G', 'B']
# Split 584801: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'F', 'G', 'B', 'E']
# Split 584802: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'F', 'G', 'E', 'B']
# Split 584803: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'G', 'B', 'E', 'F']
# Split 584804: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'G', 'B', 'F', 'E']
# Split 584805: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'G', 'E', 'B', 'F']
# Split 584806: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'G', 'E', 'F', 'B']
# Split 584807: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'G', 'F', 'B', 'E']
# Split 584808: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'D', 'G', 'F', 'E', 'B']
# Split 584809: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'B', 'D', 'F', 'G']
# Split 584810: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'B', 'D', 'G', 'F']
# Split 584811: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'B', 'F', 'D', 'G']
# Split 584812: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'B', 'F', 'G', 'D']
# Split 584813: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'B', 'G', 'D', 'F']
# Split 584814: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'B', 'G', 'F', 'D']
# Split 584815: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'D', 'B', 'F', 'G']
# Split 584816: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'D', 'B', 'G', 'F']
# Split 584817: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'D', 'F', 'B', 'G']
# Split 584818: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'D', 'F', 'G', 'B']
# Split 584819: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'D', 'G', 'B', 'F']
# Split 584820: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'D', 'G', 'F', 'B']
# Split 584821: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'F', 'B', 'D', 'G']
# Split 584822: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'F', 'B', 'G', 'D']
# Split 584823: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'F', 'D', 'B', 'G']
# Split 584824: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'F', 'D', 'G', 'B']
# Split 584825: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'F', 'G', 'B', 'D']
# Split 584826: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'F', 'G', 'D', 'B']
# Split 584827: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'G', 'B', 'D', 'F']
# Split 584828: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'G', 'B', 'F', 'D']
# Split 584829: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'G', 'D', 'B', 'F']
# Split 584830: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'G', 'D', 'F', 'B']
# Split 584831: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'G', 'F', 'B', 'D']
# Split 584832: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'E', 'G', 'F', 'D', 'B']
# Split 584833: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'B', 'D', 'E', 'G']
# Split 584834: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'B', 'D', 'G', 'E']
# Split 584835: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'B', 'E', 'D', 'G']
# Split 584836: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'B', 'E', 'G', 'D']
# Split 584837: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'B', 'G', 'D', 'E']
# Split 584838: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'B', 'G', 'E', 'D']
# Split 584839: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'D', 'B', 'E', 'G']
# Split 584840: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'D', 'B', 'G', 'E']
# Split 584841: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'D', 'E', 'B', 'G']
# Split 584842: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'D', 'E', 'G', 'B']
# Split 584843: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'D', 'G', 'B', 'E']
# Split 584844: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'D', 'G', 'E', 'B']
# Split 584845: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'E', 'B', 'D', 'G']
# Split 584846: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'E', 'B', 'G', 'D']
# Split 584847: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'E', 'D', 'B', 'G']
# Split 584848: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'E', 'D', 'G', 'B']
# Split 584849: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'E', 'G', 'B', 'D']
# Split 584850: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'E', 'G', 'D', 'B']
# Split 584851: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'G', 'B', 'D', 'E']
# Split 584852: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'G', 'B', 'E', 'D']
# Split 584853: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'G', 'D', 'B', 'E']
# Split 584854: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'G', 'D', 'E', 'B']
# Split 584855: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'G', 'E', 'B', 'D']
# Split 584856: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'F', 'G', 'E', 'D', 'B']
# Split 584857: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'G', 'B', 'D', 'E', 'F']
# Split 584858: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'G', 'B', 'D', 'F', 'E']
# Split 584859: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'G', 'B', 'E', 'D', 'F']
# Split 584860: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'G', 'B', 'E', 'F', 'D']
# Split 584861: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'G', 'B', 'F', 'D', 'E']
# Split 584862: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'G', 'B', 'F', 'E', 'D']
# Split 584863: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'G', 'D', 'B', 'E', 'F']
# Split 584864: List A: [5, 4, 2, 1, 3], List B: ['A', 'C', 'G', 'D', 'B', 'F', 'E']
# ...
# Split 604609: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'A', 'B', 'D', 'F']
# Split 604610: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'A', 'B', 'F', 'D']
# Split 604611: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'A', 'D', 'B', 'F']
# Split 604612: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'A', 'D', 'F', 'B']
# Split 604613: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'A', 'F', 'B', 'D']
# Split 604614: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'A', 'F', 'D', 'B']
# Split 604615: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'B', 'A', 'D', 'F']
# Split 604616: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'B', 'A', 'F', 'D']
# Split 604617: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'B', 'D', 'A', 'F']
# Split 604618: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'B', 'D', 'F', 'A']
# Split 604619: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'B', 'F', 'A', 'D']
# Split 604620: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'B', 'F', 'D', 'A']
# Split 604621: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'D', 'A', 'B', 'F']
# Split 604622: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'D', 'A', 'F', 'B']
# Split 604623: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'D', 'B', 'A', 'F']
# Split 604624: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'D', 'B', 'F', 'A']
# Split 604625: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'D', 'F', 'A', 'B']
# Split 604626: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'D', 'F', 'B', 'A']
# Split 604627: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'F', 'A', 'B', 'D']
# Split 604628: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'F', 'A', 'D', 'B']
# Split 604629: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'F', 'B', 'A', 'D']
# Split 604630: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'F', 'B', 'D', 'A']
# Split 604631: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'F', 'D', 'A', 'B']
# Split 604632: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'C', 'F', 'D', 'B', 'A']
# Split 604633: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'A', 'B', 'C', 'F']
# Split 604634: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'A', 'B', 'F', 'C']
# Split 604635: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'A', 'C', 'B', 'F']
# Split 604636: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'A', 'C', 'F', 'B']
# Split 604637: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'A', 'F', 'B', 'C']
# Split 604638: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'A', 'F', 'C', 'B']
# Split 604639: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'B', 'A', 'C', 'F']
# Split 604640: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'B', 'A', 'F', 'C']
# Split 604641: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'B', 'C', 'A', 'F']
# Split 604642: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'B', 'C', 'F', 'A']
# Split 604643: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'B', 'F', 'A', 'C']
# Split 604644: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'B', 'F', 'C', 'A']
# Split 604645: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'C', 'A', 'B', 'F']
# Split 604646: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'C', 'A', 'F', 'B']
# Split 604647: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'C', 'B', 'A', 'F']
# Split 604648: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'C', 'B', 'F', 'A']
# Split 604649: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'C', 'F', 'A', 'B']
# Split 604650: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'C', 'F', 'B', 'A']
# Split 604651: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'F', 'A', 'B', 'C']
# Split 604652: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'F', 'A', 'C', 'B']
# Split 604653: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'F', 'B', 'A', 'C']
# Split 604654: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'F', 'B', 'C', 'A']
# Split 604655: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'F', 'C', 'A', 'B']
# Split 604656: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'D', 'F', 'C', 'B', 'A']
# Split 604657: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'A', 'B', 'C', 'D']
# Split 604658: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'A', 'B', 'D', 'C']
# Split 604659: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'A', 'C', 'B', 'D']
# Split 604660: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'A', 'C', 'D', 'B']
# Split 604661: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'A', 'D', 'B', 'C']
# Split 604662: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'A', 'D', 'C', 'B']
# Split 604663: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'B', 'A', 'C', 'D']
# Split 604664: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'B', 'A', 'D', 'C']
# Split 604665: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'B', 'C', 'A', 'D']
# Split 604666: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'B', 'C', 'D', 'A']
# Split 604667: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'B', 'D', 'A', 'C']
# Split 604668: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'B', 'D', 'C', 'A']
# Split 604669: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'C', 'A', 'B', 'D']
# Split 604670: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'C', 'A', 'D', 'B']
# Split 604671: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'C', 'B', 'A', 'D']
# Split 604672: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'C', 'B', 'D', 'A']
# Split 604673: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'C', 'D', 'A', 'B']
# Split 604674: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'C', 'D', 'B', 'A']
# Split 604675: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'D', 'A', 'B', 'C']
# Split 604676: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'D', 'A', 'C', 'B']
# Split 604677: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'D', 'B', 'A', 'C']
# Split 604678: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'D', 'B', 'C', 'A']
# Split 604679: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'D', 'C', 'A', 'B']
# Split 604680: List A: [5, 4, 3, 2, 1], List B: ['G', 'E', 'F', 'D', 'C', 'B', 'A']
# Split 604681: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'B', 'C', 'D', 'E']
# Split 604682: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'B', 'C', 'E', 'D']
# Split 604683: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'B', 'D', 'C', 'E']
# Split 604684: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'B', 'D', 'E', 'C']
# Split 604685: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'B', 'E', 'C', 'D']
# Split 604686: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'B', 'E', 'D', 'C']
# Split 604687: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'C', 'B', 'D', 'E']
# Split 604688: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'C', 'B', 'E', 'D']
# Split 604689: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'C', 'D', 'B', 'E']
# Split 604690: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'C', 'D', 'E', 'B']
# Split 604691: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'C', 'E', 'B', 'D']
# Split 604692: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'C', 'E', 'D', 'B']
# Split 604693: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'D', 'B', 'C', 'E']
# Split 604694: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'D', 'B', 'E', 'C']
# Split 604695: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'D', 'C', 'B', 'E']
# Split 604696: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'D', 'C', 'E', 'B']
# Split 604697: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'D', 'E', 'B', 'C']
# Split 604698: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'D', 'E', 'C', 'B']
# Split 604699: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'E', 'B', 'C', 'D']
# Split 604700: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'E', 'B', 'D', 'C']
# Split 604701: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'E', 'C', 'B', 'D']
# Split 604702: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'E', 'C', 'D', 'B']
# Split 604703: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'E', 'D', 'B', 'C']
# Split 604704: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'A', 'E', 'D', 'C', 'B']
# Split 604705: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'A', 'C', 'D', 'E']
# Split 604706: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'A', 'C', 'E', 'D']
# Split 604707: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'A', 'D', 'C', 'E']
# Split 604708: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'A', 'D', 'E', 'C']
# Split 604709: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'A', 'E', 'C', 'D']
# Split 604710: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'A', 'E', 'D', 'C']
# Split 604711: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'C', 'A', 'D', 'E']
# Split 604712: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'C', 'A', 'E', 'D']
# Split 604713: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'C', 'D', 'A', 'E']
# Split 604714: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'C', 'D', 'E', 'A']
# Split 604715: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'C', 'E', 'A', 'D']
# Split 604716: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'C', 'E', 'D', 'A']
# Split 604717: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'D', 'A', 'C', 'E']
# Split 604718: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'D', 'A', 'E', 'C']
# Split 604719: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'D', 'C', 'A', 'E']
# Split 604720: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'D', 'C', 'E', 'A']
# Split 604721: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'D', 'E', 'A', 'C']
# Split 604722: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'D', 'E', 'C', 'A']
# Split 604723: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'E', 'A', 'C', 'D']
# Split 604724: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'E', 'A', 'D', 'C']
# Split 604725: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'E', 'C', 'A', 'D']
# Split 604726: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'E', 'C', 'D', 'A']
# Split 604727: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'E', 'D', 'A', 'C']
# Split 604728: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'B', 'E', 'D', 'C', 'A']
# Split 604729: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'A', 'B', 'D', 'E']
# Split 604730: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'A', 'B', 'E', 'D']
# Split 604731: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'A', 'D', 'B', 'E']
# Split 604732: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'A', 'D', 'E', 'B']
# Split 604733: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'A', 'E', 'B', 'D']
# Split 604734: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'A', 'E', 'D', 'B']
# Split 604735: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'B', 'A', 'D', 'E']
# Split 604736: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'B', 'A', 'E', 'D']
# Split 604737: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'B', 'D', 'A', 'E']
# Split 604738: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'B', 'D', 'E', 'A']
# Split 604739: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'B', 'E', 'A', 'D']
# Split 604740: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'B', 'E', 'D', 'A']
# Split 604741: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'D', 'A', 'B', 'E']
# Split 604742: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'D', 'A', 'E', 'B']
# Split 604743: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'D', 'B', 'A', 'E']
# Split 604744: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'D', 'B', 'E', 'A']
# Split 604745: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'D', 'E', 'A', 'B']
# Split 604746: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'D', 'E', 'B', 'A']
# Split 604747: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'E', 'A', 'B', 'D']
# Split 604748: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'E', 'A', 'D', 'B']
# Split 604749: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'E', 'B', 'A', 'D']
# Split 604750: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'E', 'B', 'D', 'A']
# Split 604751: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'E', 'D', 'A', 'B']
# Split 604752: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'C', 'E', 'D', 'B', 'A']
# Split 604753: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'A', 'B', 'C', 'E']
# Split 604754: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'A', 'B', 'E', 'C']
# Split 604755: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'A', 'C', 'B', 'E']
# Split 604756: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'A', 'C', 'E', 'B']
# Split 604757: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'A', 'E', 'B', 'C']
# Split 604758: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'A', 'E', 'C', 'B']
# Split 604759: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'B', 'A', 'C', 'E']
# Split 604760: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'B', 'A', 'E', 'C']
# Split 604761: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'B', 'C', 'A', 'E']
# Split 604762: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'B', 'C', 'E', 'A']
# Split 604763: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'B', 'E', 'A', 'C']
# Split 604764: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'B', 'E', 'C', 'A']
# Split 604765: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'C', 'A', 'B', 'E']
# Split 604766: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'C', 'A', 'E', 'B']
# Split 604767: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'C', 'B', 'A', 'E']
# Split 604768: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'C', 'B', 'E', 'A']
# Split 604769: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'C', 'E', 'A', 'B']
# Split 604770: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'C', 'E', 'B', 'A']
# Split 604771: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'E', 'A', 'B', 'C']
# Split 604772: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'E', 'A', 'C', 'B']
# Split 604773: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'E', 'B', 'A', 'C']
# Split 604774: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'E', 'B', 'C', 'A']
# Split 604775: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'E', 'C', 'A', 'B']
# Split 604776: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'D', 'E', 'C', 'B', 'A']
# Split 604777: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'A', 'B', 'C', 'D']
# Split 604778: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'A', 'B', 'D', 'C']
# Split 604779: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'A', 'C', 'B', 'D']
# Split 604780: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'A', 'C', 'D', 'B']
# Split 604781: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'A', 'D', 'B', 'C']
# Split 604782: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'A', 'D', 'C', 'B']
# Split 604783: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'B', 'A', 'C', 'D']
# Split 604784: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'B', 'A', 'D', 'C']
# Split 604785: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'B', 'C', 'A', 'D']
# Split 604786: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'B', 'C', 'D', 'A']
# Split 604787: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'B', 'D', 'A', 'C']
# Split 604788: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'B', 'D', 'C', 'A']
# Split 604789: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'C', 'A', 'B', 'D']
# Split 604790: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'C', 'A', 'D', 'B']
# Split 604791: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'C', 'B', 'A', 'D']
# Split 604792: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'C', 'B', 'D', 'A']
# Split 604793: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'C', 'D', 'A', 'B']
# Split 604794: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'C', 'D', 'B', 'A']
# Split 604795: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'D', 'A', 'B', 'C']
# Split 604796: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'D', 'A', 'C', 'B']
# Split 604797: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'D', 'B', 'A', 'C']
# Split 604798: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'D', 'B', 'C', 'A']
# Split 604799: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'D', 'C', 'A', 'B']
# Split 604800: List A: [5, 4, 3, 2, 1], List B: ['G', 'F', 'E', 'D', 'C', 'B', 'A']

# %% [markdown]
# ## Permutation testing in Practice
# Let's further investigate the scenario proposed in the previous lesson. Below are two samples A and B. The samples are mock data for the blood pressure of sample patients. The research study is looking to validate whether there is a statistical difference in the blood pressure of these two groups using a 5% significance level.  First, calculate the mean blood pressure of each of the two samples. Then, calculate the difference of these means. From there, use your `combT()` function, defined above, to generate all the possible combinations of the entire sample data into A-B splits of equivalent sizes as the original sets. For each of these combinations, calculate the mean blood pressure of the two groups and record the difference between these sample means. The full collection of the difference in means between these generated samples will serve as the denominator to calculate the p-value associated with the difference between the original sample means.
#
# For example, in our small handwritten example above:
#
# $\mu_a = \frac{1+2+2}{3} = \frac{5}{3}$
# and
# $\mu_b = \frac{1+3}{2} = \frac{4}{2} = 2$
#
# Giving us
#
# $\mu_a - \mu_b = \frac{5}{3} - 2 = -\frac{1}{3}$
#
# In comparison, for our various combinations we have:
#
# ([1,2,2], [1,3]):  $\mu_a - \mu_b = \frac{5}{3} - 2 = -\frac{1}{3}$
# ([1,2,3], [1,2]):  $\mu_a - \mu_b = 2 - \frac{3}{2} = \frac{1}{2}$
# ([1,2,1], [2,3]):  $\mu_a - \mu_b = \frac{4}{3} - \frac{5}{3} = -\frac{1}{2}$
# ([1,1,3], [2,2]):  $\mu_a - \mu_b = \frac{5}{3} - 2 = -\frac{1}{3}$
# ([2,2,3], [1,1]):  $\mu_a - \mu_b = \frac{7}{3} - 1 = \frac{4}{3}$
#
# A standard hypothesis test for this scenario might be:
#
# $H_0: \mu_a = \mu_b$
# $H_1: \mu_a < \mu_b$
#
# Thus comparing our sample difference to the differences of our possible combinations, we look at the number of experiments from our combinations space that were the same or greater than our sample statistic, divided by the total number of combinations. In this case, 4 out of 5 of the combination cases produced the same or greater differences in the two sample means. This value .8 is a strong indication that we cannot refute the null hypothesis for this instance.

# %%
a = [109.6927759 , 120.27296943, 103.54012038, 114.16555857,
       122.93336175, 110.9271756 , 114.77443758, 116.34159338,
       112.66413025, 118.30562665, 132.31196515, 117.99000948]
b = [123.98967482, 141.11969004, 117.00293412, 121.6419775 ,
       123.2703033 , 123.76944385, 105.95249634, 114.87114479,
       130.6878082 , 140.60768727, 121.95433026, 123.11996767,
       129.93260914, 121.01049611]

# %%
# Your code here
# ⏰ Expect your code to take several minutes to run

# %% [markdown]
# ## T-test revisited
#
# The parametric statistical test equivalent to our permutation test above would be a t-test of the two groups. Perform a t-test on the same data above in order to calculate the p-value. How does this compare to the above results?

# %%
# Your code here

# %% [markdown]
# ## Bootstrap applied
#
# Use your code above to apply the bootstrap technique to this hypothesis testing scenario. Here's a pseudo-code outline for how to do this:
#
# 1. Compute the difference between the sample means of A and B
# 2. Initialize a counter for the number of times the difference of the means of resampled samples is greater then or equal to the difference of the means of the original samples
# 3. Repeat the following process 10,000 times:
#     1. Use the bootstrap sampling function you used above to create new resampled versions of A and B
#     2. Compute the difference between the means of these resampled samples
#     3. If the difference between the means of the resampled samples is greater then or equal to the original difference, add 1 the counter you created in step 2
# 4. Compute the ratio between the counter and the number of simulations (10,000) that you performed
#     > This ratio is the percentage of simulations in which the difference of sample means was greater than the original difference

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you practice coding modern statistical resampling techniques of the 20th century! You also started to compare these non-parametric methods to other parametric methods such as the t-test that we previously discussed.
